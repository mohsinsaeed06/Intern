# %%
from ultralytics import YOLO
image_path = r'D:\PythonProject1\Intern\Images\image5.jpg'

model = YOLO('yolov8n.pt')
results = model(image_path)
results[0].show()
# Out:
# image 1/1 D:\PythonProject1\Intern\Images\image5.jpg: 512x640 8 persons, 1 car, 1 parking meter, 310.5ms
# Speed: 21.4ms preprocess, 310.5ms inference, 30.5ms postprocess per image at shape (1, 3, 512, 640)
