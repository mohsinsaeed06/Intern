# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img=cv2.imread('D:\PythonProject1\Intern\Images\WhatsApp Image 2026-06-21 at 9.36.31 PM.jpeg',cv2.IMREAD_GRAYSCALE)

blurr=cv2.GaussianBlur(img,(3,3),0)
l1,binary=cv2.threshold(blurr,129,255,cv2.THRESH_BINARY)
print(l1)
kernel=np.ones((3,3))
opened=cv2.morphologyEx(binary,cv2.MORPH_OPEN,kernel)
cleaned=cv2.morphologyEx(opened,cv2.MORPH_CLOSE,kernel)
# Out:
# 129.0
# <>:5: SyntaxWarning: invalid escape sequence '\P'
# <>:5: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\Mohsin's PC\AppData\Local\Temp\ipykernel_5464\916420088.py:5: SyntaxWarning: invalid escape sequence '\P'
#   img=cv2.imread('D:\PythonProject1\Intern\Images\WhatsApp Image 2026-06-21 at 9.36.31 PM.jpeg',cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(img,cmap='gray')


plt.show()

# %%
plt.imshow(cleaned, cmap='gray')
plt.show()

# %%
plt.imshow(img,cmap='gray')
plt.show()

# %%
img=cv2.imread('D:\PythonProject1\Intern\Images\WhatsApp Image 2026-06-21 at 9.36.31 PM.jpeg',cv2.IMREAD_GRAYSCALE)
blurr=cv2.GaussianBlur(img,(3,3),0)
plt.imshow(blurr,cmap='gray')
plt.show()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\Mohsin's PC\AppData\Local\Temp\ipykernel_5464\2540719311.py:1: SyntaxWarning: invalid escape sequence '\P'
#   img=cv2.imread('D:\PythonProject1\Intern\Images\WhatsApp Image 2026-06-21 at 9.36.31 PM.jpeg',cv2.IMREAD_GRAYSCALE)

# %%
# l1,binary=cv2.threshold(blurr,180,255,cv2.THRESH_BINARY)
# plt.imshow(binary,cmap='gray')
# plt.show()

# %%
opened=cv2.morphologyEx(binary,cv2.MORPH_OPEN,kernel)
plt.imshow(opened,cmap='gray')
plt.show()

# %%
kernel=np.ones((1,1))

cleaned=cv2.morphologyEx(opened,cv2.MORPH_CLOSE,kernel)
plt.imshow(cleaned,cmap='gray')
plt.show()

# %%
plt.imshow(img,cmap='gray')


plt.show()

# %%
kernel = np.ones((2,1))

opened = cv2.erode(img, kernel,iterations=1)
kernel = np.ones((1,2))

opened = cv2.erode(opened, kernel,iterations=1)
kernel = np.ones((1,3))
opened = cv2.erode(opened, kernel,iterations=1)
kernel = np.ones((1,1))
opened = cv2.erode(opened, kernel,iterations=1)



plt.imshow(opened,cmap='gray')
plt.show()

# %%
kernel = np.ones((2,1))

opened = cv2.erode(img, kernel,iterations=1)
kernel = np.ones((1,2))

opened = cv2.erode(opened, kernel,iterations=1)
kernel = np.ones((1,3))
opened = cv2.erode(opened, kernel,iterations=1)
kernel = np.ones((1,1))
opened = cv2.erode(opened, kernel,iterations=1)
kernel = np.ones((3, 3))


opened = cv2.morphologyEx(opened, cv2.MORPH_CLOSE, kernel, iterations=1)

kernel= np.ones((2, 2))
opened = cv2.dilate(opened, kernel, iterations=1)



plt.imshow(opened,cmap='gray')
plt.show()
